# %%
### Prime Number
num=int(input("Enter a number:"))
if num>1:
    for i in range(2,num):
        if num%i ==0:
            print(num,"is not a prime number")
            break
        else:
            print(num,"is a prime number")
else:
    print(num,"is not a prime number")
# Out:
# Enter a number: 54
# 54 is not a prime number

# %%
### Product of Random Numbers
import random
num1 =random.randint(1,10)
num2=random.randint(1,10)
print(f"what is {num1}*{num2}?")
user_answer=int(input("Enter your answer:"))
correct_answer=num1*num2
if user_answer ==correct_answer:
    print("correct")
else:
    print(f"Incorrect ! The correct answer is {correct_answer}")
# Out:
# what is 9*8?
# Enter your answer: 55
# Incorrect ! The correct answer is 72

# %% [markdown]
# ###### Exercise 3: Squares of Even/Odd Numbers
# Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code

# %%
# Choice: Set choice = "even" or "odd"
choice = "odd"   # change to "odd" if needed
print(f"Squares of all {choice} numbers between 100 and 200:")
for num in range(100, 201):
    if choice == "even" and num % 2 == 0:
        print(num, "->", num ** 2)
    elif choice == "odd" and num % 2 != 0:
        print(num, "->", num ** 2)
# Out:
# Squares of all odd numbers between 100 and 200:
# 101 -> 10201
# 103 -> 10609
# 105 -> 11025
# 107 -> 11449
# 109 -> 11881
# 111 -> 12321
# 113 -> 12769
# 115 -> 13225
# 117 -> 13689
# 119 -> 14161
# 121 -> 14641
# 123 -> 15129
# 125 -> 15625
# 127 -> 16129
# 129 -> 16641
# 131 -> 17161
# 133 -> 17689
# 135 -> 18225
# 137 -> 18769
# 139 -> 19321
# 141 -> 19881
# 143 -> 20449
# 145 -> 21025
# 147 -> 21609
# 149 -> 22201
# 151 -> 22801
# 153 -> 23409
# 155 -> 24025
# 157 -> 24649
# 159 -> 25281
# 161 -> 25921
# 163 -> 26569
# 165 -> 27225
# 167 -> 27889
# 169 -> 28561
# 171 -> 29241
# 173 -> 29929
# 175 -> 30625
# 177 -> 31329
# 179 -> 32041
# 181 -> 32761
# 183 -> 33489
# 185 -> 34225
# 187 -> 34969
# 189 -> 35721
# 191 -> 36481
# 193 -> 37249
# 195 -> 38025
# 197 -> 38809
# 199 -> 39601

# %%
### Problem Statement (Question): Hospital Billing System
# Given Data
Room_charges_per_day=2000
consultation_fee=1500
Lab_test_cost=300
medicine_charges=2400
# Patient details
no_stayed=4
no_lab_test=3
# calculations
total_room_charges=Room_charges_per_day*no_stayed
lab_total=Lab_test_cost * no_lab_test

# Before discount bill
total_before_discount= total_room_charges+lab_total+ medicine_charges
 ## discounts
if total_before_discount>10000:
   discount= total_before_discount*0.10
else:
    discount=0

final_bill=total_before_discount- discount
## output
print("----- Hospital Billing Summary -----")
print("Room Charges:", total_room_charges)
print("Consultation Fee:", consultation_fee)
print("Lab Test Charges:", lab_total)
print("Medicine Charges:", medicine_charges)
print("Total Before Discount:", total_before_discount)
print("Discount Applied:", discount)
print("Final Bill Amount:", final_bill)
# Out:
# ----- Hospital Billing Summary -----
# Room Charges: 8000
# Consultation Fee: 1500
# Lab Test Charges: 900
# Medicine Charges: 2400
# Total Before Discount: 11300
# Discount Applied: 1130.0
# Final Bill Amount: 10170.0
