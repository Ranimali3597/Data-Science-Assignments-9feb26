# %% [markdown]
# ##### Descriptive Analytics and Data Preprocessing on Sales & Discounts Dataset

# %% [markdown]
# ###### Descriptive Analytics for Numerical Columns

# %% [raw]
# ●	Objective: To compute and analyze basic statistical measures for numerical columns in the dataset.
# ●	Steps:
# 	Load the dataset into a data analysis tool or programming environment (e.g., Python with pandas library).
# 	Identify numerical columns in the dataset.
# 	Calculate the mean, median, mode, and standard deviation for these columns.
# 	Provide a brief interpretation of these statistics.

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("sales_data_with_discounts.csv")
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
df.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
## Identify numerical columns
numerical_col=df.select_dtypes(include=['int64','float64'])
numerical_col
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        15      12100             181500          11.654820     21153.498820
# 1        10      10100             101000          11.560498     11676.102961
# 2         7      16100             112700           9.456886     10657.910157
# 3         6      20100             120600           6.935385      8364.074702
# 4         3       8100              24300          17.995663      4372.946230
# ..      ...        ...                ...                ...              ...
# 445       2       1300               2600          15.475687       402.367873
# 446       6       2600              15600          17.057027      2660.896242
# 447       2       1600               3200          18.965550       606.897606
# 448       3       1900               5700          16.793014       957.201826
# 449       1       3100               3100          15.333300       475.332295
#
#      Net Sales Value
# ...

# %%
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %%
mean_values=numerical_col.mean()
mean_values
# Out:
# Volume                   5.066667
# Avg Price            10453.433333
# Total Sales Value    33812.835556
# Discount Rate (%)       15.155242
# Discount Amount       3346.499424
# Net Sales Value      30466.336131
# dtype: float64

# %%
median_values=numerical_col.median()
median_values
# Out:
# Volume                  4.000000
# Avg Price            1450.000000
# Total Sales Value    5700.000000
# Discount Rate (%)      16.577766
# Discount Amount       988.933733
# Net Sales Value      4677.788059
# dtype: float64

# %%
mode_values=numerical_col.mode().iloc[0]
mode_values
# Out:
# Volume                   3.000000
# Avg Price              400.000000
# Total Sales Value    24300.000000
# Discount Rate (%)        5.007822
# Discount Amount         69.177942
# Net Sales Value        326.974801
# Name: 0, dtype: float64

# %%
std_values=numerical_col.std()
std_values
# Out:
# Volume                   4.231602
# Avg Price            18079.904840
# Total Sales Value    50535.074173
# Discount Rate (%)        4.220602
# Discount Amount       4509.902963
# Net Sales Value      46358.656624
# dtype: float64

# %%
summary=pd.DataFrame({
    'Mean': mean_values,
    'Median': median_values,
    'Mode': mode_values,
    'Std Deviation': std_values 
})
print(summary)
# Out:
#                            Mean       Median          Mode  Std Deviation
# Volume                 5.066667     4.000000      3.000000       4.231602
# Avg Price          10453.433333  1450.000000    400.000000   18079.904840
# Total Sales Value  33812.835556  5700.000000  24300.000000   50535.074173
# Discount Rate (%)     15.155242    16.577766      5.007822       4.220602
# Discount Amount     3346.499424   988.933733     69.177942    4509.902963
# Net Sales Value    30466.336131  4677.788059    326.974801   46358.656624

# %% [markdown]
# ##### Interpretation (Brief Explanation)
#
# Mean:
# Represents the average value of the column.
# Useful for understanding the central tendency.
#
# Median:
# The middle value when data is sorted.
# More reliable than mean if data has outliers.
#
# Mode:
# The most frequent value in the dataset.
# Helps identify common or repeated values.
#
# Standard Deviation:
# Indicates how spread out the data is.
# A high standard deviation means data values vary widely.
# A low standard deviation means data values are close to the mean.

# %% [markdown]
# #### Data Visualization

# %% [raw]
# ●	Objective: To visualize the distribution and relationship of numerical and categorical variables in the dataset.
# ●	Histograms:
# 	Plot histograms for each numerical column.
# 	Analyze the distribution (e.g., skewness, presence of outliers) and provide inferences.
# ●	Box Plots:
# 	Create boxplots for numerical variables to identify outliers and the interquartile range.
# 	Discuss any findings, such as extreme values or unusual distributions.
# ●	Bar Chart Analysis for Categorical Column:
# 	Identify categorical columns in the dataset.
# 	Create bar charts to visualize the frequency or count of each category.
# 	Analyze the distribution of categories and provide insights

# %% [markdown]
# #### 1.Histogram

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

for col in numerical_cols:
    plt.figure(figsize=(7,4))
    sns.histplot(df[col], kde=True)
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %% [raw]
# 1.Volume:
# The distribution is right-skewed.
# Majority of the volumes fall between 2 and 6 units.
# A small number of transactions have very high volumes (up to 30 units), causing outliers.
# Typical customer orders small quantities, but there are occasional bulk orders, resulting in positive skew.
# 2.Avg Price
# The distribution is highly right-skewed.
# Most Avg Price values are clustered at the low end (below ₹2000).
# A few values extend up to ₹60,000, creating extreme outliers.
# This indicates that while most products are low-priced, a small number of very expensive products pull the scale upward.
# Dataset contains many low-priced items and very few highly-priced premium items, causing long-tailed skewness.
# 3.Total Sales value:
# Shows a strong right-skew.
# Most transactions fall below ₹20,000.
# Some transactions reach ₹200,000, creating significant outliers.
# Sales vary widely. Many small transactions occur, with a few very high-value orders contributing heavily to total revenue.
# 4.Discount Rate:
# Distribution appears bimodal:
# One peak around 7–10%
# Another peak around 16–19%
# Shows moderate spread but no extreme outliers.
# The business uses two common discount ranges—a smaller discount (7–10%) and a higher discount (16–19%).
# Discount rates are fairly consistent.
# 5.Discount Amount:
# The distribution is heavily right-skewed.
# Most discount amounts are low, under ₹2000.
# A few large discounts (up to ₹25,000) occur on high-value purchases, creating a long tail.
# Discount amount varies based on transaction size. Small discounts are common; large discounts occur only for big-ticket orders
# 6.Net Sales Value:
# The distribution is heavily right-skewed.
# Most transactions have lower net sales values, while a few have very high values.
# Large spread indicates diverse customer spending levels.

# %% [markdown]
# ##### 2. Boxplot

# %%
for col in numerical_cols:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)
    #plt.show()

# %%
# Calculate quartiles
quartiles = numerical_col.quantile([0.25, 0.50, 0.75])

# Calculate IQR
IQR = quartiles.loc[0.75] - quartiles.loc[0.25]

print("Quarterly Values (Q1, Q2, Q3):")
print(quartiles)

print("\nInterquartile Range (IQR):")
print(IQR)
# Out:
# Quarterly Values (Q1, Q2, Q3):
#       Volume  Avg Price  Total Sales Value  Discount Rate (%)  \
# 0.25     3.0      465.0             2700.0          13.965063
# 0.50     4.0     1450.0             5700.0          16.577766
# 0.75     6.0    10100.0            53200.0          18.114718
#
#       Discount Amount  Net Sales Value
# 0.25       460.459304      2202.208645
# 0.50       988.933733      4677.788059
# 0.75      5316.495427     47847.912852
#
# Interquartile Range (IQR):
# Volume                   3.000000
# Avg Price             9635.000000
# Total Sales Value    50500.000000
# Discount Rate (%)        4.149656
# Discount Amount       4856.036123
# Net Sales Value      45645.704206
# dtype: float64

# %% [raw]
# 1.Volume:
# The boxplot shows a small IQR,i.e.values lie between 3 and 6 units.
# Several upper outliers appear, with volumes exceeds to 30.
# This indicates  occasional bulk purchases, but typical volumes invovle low quantities.
# Conclusion:
# Volume has moderate variability with some high-value outliers.
# 2.Avg Price:
# The box plot displays a very large upper whisker and numerous extreme outliers.
# The IQR is narrow at the lower end, meaning most prices are low, but a few items have very high prices.
# Conclusion:
# Avg Price is highly skewed with significant outliers—indicating the presence of premium-priced products.
# 3.Total Sales Value:
# Similar to Avg Price, the box plot reveals a long upper tail and many outliers.
# The IQR is small compared to the full range, meaning typical sales values are low-to-medium.
# Extreme values reach up to ₹200,000.
# Conclusion:
# Total Sales Value shows extreme variability with multiple high-value outliers, likely from large total sales.
# 4.Discount Rate (%):
# The IQR is moderate, and whiskers are relatively short.
# Only a few potential outliers appear.
# Values are grouped mostly between 8% and 18%.
# Conclusion:
# Discount Rate is consistent, with minimal outliers.
# The business uses fairly stable discount percentages across products.
# 5.Discount Amount:
# The box plot shows a high number of upper outliers, similar to price and sales metrics.
# Most discount values are low (small IQR), but some discounts go above ₹25,000.
# Conclusion:
# Discount Amount varies widely and depends strongly on the total purchase value, causing large outliers.
# 6.Net Sales Value
# Strong right skew with many large outliers.
# IQR is small compared to the maximum value.
# Outliers represent high-value net sales transactions.
# Conclusion:
# Net Sales Value contains extreme outliers and high variability, indicating a mix of regular small sales and occasional very large sales.

# %% [markdown]
# ##### 3.Bar Chart Analysis for Categorical Column

# %%
categorical_cols = df.select_dtypes(include=['object']).columns

for col in categorical_cols:
    plt.figure(figsize=(8,4))
    df[col].value_counts().plot(kind='bar')
    plt.title(f"Bar Chart for {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

# %% [raw]
# 1.Date:
# No variation in day-wise distribution.
#
# 2.Day:
# Only Thursday appears in the provided sample, indicating the dataset may represent sales on a single day.
# No variation in day-wise distribution
#
# 3.SKU:
# No variation in SKU-wise distribution.
#
# 4.City:
# Only City C is present in the sample.
# If full dataset contains more cities, bar chart will show which city has the highest sales entries.
#
# 5.BU:
# Only Mobiles appear, meaning this dataset is focused on the mobile business segment.
#
# 6.Brand:
# Jeera brand has highest frequency.
#
# 7.Model:
# No variation .

# %% [markdown]
# ##### Conclusion
# 	Summarize the key findings from the descriptive analytics and data visualizations.

# %% [raw]
# The descriptive statistics and data visualizations reveal several important patterns in the dataset. Most numerical variables—such as Avg Price, Total Sales Value, Discount Amount, and Net Sales Value—exhibit strong right-skewness, where the mean is much higher than the median. This indicates the presence of high-value outliers, meaning a small number of large transactions significantly influence the overall averages.
# Boxplots further confirm this by showing long upper whiskers and many high-end outliers, especially for monetary variables.
#
# The Volume column shows moderate variability with a few bulk purchases acting as outliers, while the Discount Rate (%) is the most consistent measure, with a small spread and minimal outliers. This indicates stable discounting practices across transactions.
#
# Histograms show that most values in monetary columns cluster at the lower end with a long tail toward higher values, reinforcing the presence of extreme values. Bar charts for categorical variables highlight limited diversity in categories such as BU, City, and Day in the provided sample, while Brand shows some variation in frequency.
